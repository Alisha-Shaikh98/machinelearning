# %% [markdown]
# <a href="https://colab.research.google.com/github/Alisha-Shaikh98/machinelearning/blob/main/Book_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neighbors import NearestNeighbors
import pandas as pd

# %%
books = pd.read_csv("/content/BX_Books.csv",encoding='latin-1', sep=';', on_bad_lines='skip')
users = pd.read_csv("/content/BX-Users.csv",encoding='latin-1', sep=';', on_bad_lines='skip')
ratings = pd.read_csv("/content/BX-Book-Ratings.csv",encoding='latin-1', sep=';', on_bad_lines='skip')

# %%
print(books.head())
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                Publisher  \
# 0    Mark P. O. Morford                2002  Oxford University Press
# 1  Richard Bruce Wright                2001    HarperFlamingo Canada
# 2          Carlo D'Este                1991          HarperPerennial
# 3      Gina Bari Kolata                1999     Farrar Straus Giroux
# 4       E. J. W. Barber                1999   W. W. Norton & Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
print(ratings.head())
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(users.head())
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
# Filter users with less than 200 ratings
user_counts = ratings.groupby('User-ID').size()
active_users = user_counts[user_counts >=200].index
filtered_ratings = ratings[ratings['User-ID'].isin(active_users)]

print(user_counts)
# Out:
# User-ID
# 2          1
# 7          1
# 8         18
# 9          3
# 10         2
#           ..
# 278846     2
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Length: 105283, dtype: int64

# %%
# Filter books with less than 200 ratings
book_counts = filtered_ratings.groupby('ISBN').size()
popular_books = book_counts[book_counts >= 200].index
filtered_ratings = filtered_ratings[filtered_ratings['ISBN'].isin(popular_books)]

# %%
book_data = pd.merge(filtered_ratings,books, on='ISBN')
book_data.head()
# Out:
#    User-ID        ISBN  Book-Rating                 Book-Title   Book-Author  \
# 0   277427  0316666343            0  The Lovely Bones: A Novel  Alice Sebold
# 1   277427  0385504209            8          The Da Vinci Code     Dan Brown
# 2   277427  0971880107            0                Wild Animus  Rich Shapero
# 3   277478  0971880107            0                Wild Animus  Rich Shapero
# 4   277639  0440211727            8             A Time to Kill  JOHN GRISHAM
#
#   Year-Of-Publication      Publisher  \
# 0                2002  Little, Brown
# 1                2003      Doubleday
# 2                2004        Too Far
# 3                2004        Too Far
# 4                1992           Dell
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0316666343.0...
# 1  http://images.amazon.com/images/P/0385504209.0...
# 2  http://images.amazon.com/images/P/0971880107.0...
# 3  http://images.amazon.com/images/P/0971880107.0...
# ...

# %%
# Pivot Table
book_user_matrix = book_data.pivot_table(index='Book-Title',columns='User-ID', values='Book-Rating').fillna(0)
book_user_matrix.head()
# Out:
# User-ID                                          2766    2977    3363    \
# Book-Title
# A Time to Kill                                      0.0     0.0     0.0
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     0.0     0.0     0.0
# The Da Vinci Code                                   0.0     0.0     0.0
# The Firm                                            0.0     0.0     0.0
# The Lovely Bones: A Novel                           9.0     0.0     0.0
#
# User-ID                                          4017    6251    6543    \
# Book-Title
# A Time to Kill                                      0.0     0.0     0.0
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     0.0     0.0     0.0
# The Da Vinci Code                                   0.0     0.0     0.0
# The Firm                                            0.0     0.0     0.0
# The Lovely Bones: A Novel                          10.0     0.0     0.0
#
# ...

# %%
model = NearestNeighbors(metric='cosine', algorithm='brute')
model.fit(book_user_matrix.values)

def get_recommends (book_title):
    book_idx = book_user_matrix.index.get_loc(book_title) #index
    distances, indices = model.kneighbors([book_user_matrix.iloc[book_idx]], n_neighbors=6)
    recommended_books = []
    for i in range(1, len(indices[0])):
        title = book_user_matrix.index[indices[0][i]]
        distance = distances[0][i]
        recommended_books = [book_title, recommended_books]

    return [book_title, recommended_books]

# %%
get_recommends("A Time to Kill")
# Out:
# ['A Time to Kill',
#  ['A Time to Kill',
#   ['A Time to Kill',
#    ['A Time to Kill', ['A Time to Kill', ['A Time to Kill', []]]]]]]
